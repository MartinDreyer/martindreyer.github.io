# %%
# %pip install

# %%
import pandas as pd
df = pd.read_csv("airbnb_listings.csv")
df.head()
# Out:
#                     id                                       listing_url  \
# 0   987432863281005716   https://www.airbnb.com/rooms/987432863281005716
# 1   923280616854757068   https://www.airbnb.com/rooms/923280616854757068
# 2              6739945              https://www.airbnb.com/rooms/6739945
# 3   738353373575085526   https://www.airbnb.com/rooms/738353373575085526
# 4  1113722678442011271  https://www.airbnb.com/rooms/1113722678442011271
#
#         scrape_id last_scraped       source                             name  \
# 0  20240330234305   2024-03-31  city scrape   Rummelugt værelse /faciliteter
# 1  20240330234305   2024-03-31  city scrape                        Apartment
# 2  20240330234305   2024-03-31  city scrape        Tæt på centrum og strand.
# 3  20240330234305   2024-03-31  city scrape  Nice Location 5 min from metro!
# 4  20240330234305   2024-03-31  city scrape        Charming apartment in CPH
#
#                                          description  \
# ...
